# %%
# bài 1
try:
    a , b = map(float,input().split())
    print(f'{a/b:.2f}')
except ZeroDivisionError:
    print("Loi chia khong")

# %%
# bài 2
try:
    a = list(map(int , input().split()))
    print(a[len(a)])
except IndexError:
    print("list index out of range")

# %%
# bài 3
def Sum_ofn(n):
    ans = 0
    while (n != 0):
        ans += (n%10)*(n%10)
        n //= 10
    return ans
try:
    a = int(input())
    seen = set()
    happy = True
    while (a != 1):
        if a in seen:
            happy = False
            break
        seen.add(a)
        a = Sum_ofn(a)
    if (happy):
        print("YES")
    else:
        print("NO")
except ValueError:
    print("invalid literal for int() with base 10: '1.0'")

# %%
# bài 4
try:
    a , b = map(int,input().split())
except ValueError:
    print("Must be interger")
else:
    print(a + b)
finally:
    print("The end of Program")

# %%
# bài 5
a = list(map(str,input().split()))
for i in range(0 , len(a)):
    try:
        a[i] = int(a[i])
    except (ValueError , TypeError):
        print(f"Can't be generated {a[i]} to interger")
print(a)

# %%
# bài 6
try:
    a = int(input())
    if (a < 0):
        raise ValueError
    print(f'{a**0.5:.2f}')
except ValueError:
    print("So am")

# %%
# bài 7
try:
    age = int(input())
    if (age < 0):
        raise ValueError
    print(2025 - age)
except (ValueError , TypeError):
    print("Tuoi khong hop le")

# %%
# bài 8
try:
    File_name = input()
    a = File_name.split(".")
    if (len(a) < 2):
        raise ValueError
    a[1] = a[1].lower()
    if a[1] != "txt" and a[1] != "zip":
        raise ValueError
    print("Doc file thanh cong")
except ValueError:
    print("File khong hop le")

# %%
# bài 9
try:
    number = input()
    number = int(number)
    print(number)
except (ValueError , TypeError):
    print("Chuoi khong hop le")

# %%
# bài 10
try:
    a = list(map(int , input().split()))
    met = set()
    Error = False
    sum = 0
    for i in range(0 , len(a)):
        if a[i] not in met:
            met.add(a[i])
        else:
            Error = True
            break
        sum += a[i]
    if Error:
        raise ValueError
    print(sum)
except (ValueError , TypeError):
    print("Mang khong hop le")

# %%
# bài 11
import re
T = int(input())
for _ in range(T):
    s = input()
    try:
       re.compile(s)
       print("True")
    except:
       print("False")
